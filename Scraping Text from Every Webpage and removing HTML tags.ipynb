# %%
import numpy as np
import pandas as pd

# %%
# !ls
# Out:
#  Input.xlsx				     StopWords-20240103T040728Z-001.zip
#  MasterDictionary-20240103T040658Z-001.zip  'Text Analysis.docx'
#  Objective.docx				    'text files'
# 'Output Data Structure.xlsx'		     Untitled.ipynb

# %%
df = pd.read_excel("Input.xlsx")

# %%
df.shape
# Out:
# (100, 2)

# %%
df["URL"]
# Out:
# 0     https://insights.blackcoffer.com/rising-it-cit...
# 1     https://insights.blackcoffer.com/rising-it-cit...
# 2     https://insights.blackcoffer.com/internet-dema...
# 3     https://insights.blackcoffer.com/rise-of-cyber...
# 4     https://insights.blackcoffer.com/ott-platform-...
#                             ...
# 95    https://insights.blackcoffer.com/what-is-the-r...
# 96    https://insights.blackcoffer.com/impact-of-cov...
# 97    https://insights.blackcoffer.com/contribution-...
# 98    https://insights.blackcoffer.com/how-covid-19-...
# 99    https://insights.blackcoffer.com/how-will-covi...
# Name: URL, Length: 100, dtype: object

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
class Scraper:
    url = ""
    index = 0
    def __init__(self):
        self.url = ""
        self.index = NA
        
    def __init__(self, url , index):
        self.url = url
        self.index = index
        
    def GetText(self):
        print(f"Getting text for index {self.index} from URL: {self.url}")
        
        response = requests.get(self.url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            text = soup.get_text()
            return text
        else:
            print(f"Failed to retrieve the webpage for index {self.index}")
            return "Failed to retrieve the webpage"
        
    def SetIndex(self, curr_index):
        print(f"Setting index for URL: {self.url} to {curr_index}")
        self.index = curr_index
        
    def CleanText(self , string):
        print("Removing HTML tags...")
        without_tags = re.sub(r'<[^>]*>', ' ', string)
    
        print("Replacing multiple spaces with a single space...")
        without_extra_spaces = re.sub(r'\s{2,}', ' ', without_tags)
    
        print("Trimming leading and trailing spaces...")
        cleaned_text = without_extra_spaces.strip()
    
        print("Removing empty lines...")
        cleaned_text_no_empty_lines = "\n".join(line for line in cleaned_text.split("\n") if line.strip())

        print("Removing multiple whitespaces...")
        cleaned_text_single_space = re.sub(r'\s+', ' ', cleaned_text_no_empty_lines)        
 
        cleaned_text = re.sub(r'\n\s*\n', '\n\n', text)
        cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
        return cleaned_text.strip()
    
    def SaveText(self , Text):
        name = "text files/text_file" + "-" + (str)(index)
        with open(name , 'w') as file:
            file.write(text)
        print(f"text has been saved to '{name}'")

# %%
for index, row in df.iterrows():
    myscraper = Scraper(row[1] , index)
    
    text = myscraper.GetText()
    
    myscraper.SetIndex(index)
    
    cleaned_text = myscraper.CleanText(text)
    
    myscraper.SaveText(text)
# Out:
# Getting text for index 0 from URL: https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/
# Setting index for URL: https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/ to 0
# Removing HTML tags...
# Replacing multiple spaces with a single space...
# Trimming leading and trailing spaces...
# Removing empty lines...
# Removing multiple whitespaces...
# text has been saved to 'text files/text_file-0'
# Getting text for index 1 from URL: https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/
# Setting index for URL: https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/ to 1
# Removing HTML tags...
# Replacing multiple spaces with a single space...
# ...
